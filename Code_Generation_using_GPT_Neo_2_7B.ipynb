# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjulikasharma/gpt-neo-code-generation/blob/main/Code_Generation_using_GPT_Neo_2_7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 50.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 28.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 96.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.9 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
#Set up generator
generator = pipeline('text-generation', model= 'EleutherAI/gpt-neo-2.7B')

# %%
# Generate text using prompt
prompt = 'define a function to add two numbers in python'

# %%
res = generator(prompt, max_length = 500, do_sample=True, temperature =0.9)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
#output prompt
print(res[0]['generated_text'])
# Out:
# define a function to add two numbers in python.
# and in the function I want to return as a number with the addition. So I use the if and else part, but it will always return 0 and the value is wrong.
# Code:
# def add_numbers_with_addition(self, first_number, second_number):
#     if first_number <= second_number:
#         print("first number is less than second number")
#     elif first_number > second_number:
#         print("first number is not bigger than second number")
#     else:
#         print("first number is bigger than second number")
#     return first_number + second_number
#
# if first_number <= second_number:
#     return first_number + add_numbers_with_addition(first_number,second_number)
# elif first_number > second_number:
#     return first_number - add_numbers_with_addition(first_number,second_number)
# else:
#     return first_number
#
# But it just returns 0 all the time.
#
# A:
#
# return first_number + (second_number - first_number)
#
# ...
